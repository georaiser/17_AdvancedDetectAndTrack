# %%
#!/usr/bin/env python3
import torch
import cv2
import time
import os
import logging
import numpy as np
import pandas as pd
from ultralytics import YOLO
from typing import Dict, Tuple, Optional, List
from collections import deque
import re

# OCR imports
try:
    import pytesseract
    TESSERACT_AVAILABLE = True
except ImportError:
    TESSERACT_AVAILABLE = False

try:
    import easyocr
    EASYOCR_AVAILABLE = True
except ImportError:
    EASYOCR_AVAILABLE = False

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')
logger = logging.getLogger(__name__)

class GPUManager:
    """Simplified GPU memory management"""
    
    @staticmethod
    def setup():
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
            torch.backends.cudnn.benchmark = True
            torch.backends.cudnn.deterministic = False
            logger.info("GPU optimized")
            return True
        logger.warning("Using CPU (slower)")
        return False
    
    @staticmethod
    def monitor():
        if torch.cuda.is_available():
            device = torch.cuda.current_device()
            used = torch.cuda.memory_allocated(device) / 1024**3
            total = torch.cuda.get_device_properties(device).total_memory / 1024**3
            utilization = (used / total) * 100
            
            if utilization > 85:
                torch.cuda.empty_cache()
            return utilization
        return 0.0

class FPSCounter:
    """Simple FPS calculator"""
    def __init__(self, buffer_size=30):
        self.timestamps = deque(maxlen=buffer_size)
    
    def tick(self):
        self.timestamps.append(time.time())
    
    def get_fps(self) -> float:
        if len(self.timestamps) < 2:
            return 0.0
        return len(self.timestamps) / (self.timestamps[-1] - self.timestamps[0])

class ChileanPlateValidator:
    """Chilean license plate format validation and correction"""
    
    ALLOWED_LETTERS = set("BCDFGHJKLPRSTWVXYZ")
    MODERN_PATTERN = re.compile(r'^[BCDFGHJKLPRSTWVXYZ]{4}\d{2}$')
    LEGACY_PATTERN = re.compile(r'^[A-Z]{2}\d{4}$')
    
    @staticmethod
    def clean_and_correct(text: str) -> str:
        """Clean and correct OCR text for Chilean plates"""
        if not text:
            return ""
        
        # Basic cleaning
        cleaned = ''.join(c.upper() for c in text if c.isalnum())
        if len(cleaned) != 6:
            return cleaned
        
        # Apply corrections based on expected format
        result = ""
        expected_format = "LLLLNN" if cleaned[:4].isalpha() else "LLNNNN"
        
        for i, char in enumerate(cleaned):
            if i >= len(expected_format):
                break
            
            if expected_format[i] == 'L':  # Should be letter
                corrected = ChileanPlateValidator._correct_to_letter(char)
            else:  # Should be number
                corrected = ChileanPlateValidator._correct_to_number(char)
            
            result += corrected
        
        return result
    
    @staticmethod
    def _correct_to_letter(char: str) -> str:
        """Convert character to valid Chilean plate letter"""
        # Number to letter mapping
        if char.isdigit():
            mapping = {'0': 'D', '1': 'L', '2': 'Z', '3': 'B', '4': 'H', 
                      '5': 'S', '6': 'G', '7': 'T', '8': 'B', '9': 'G'}
            char = mapping.get(char, char)
        
        # Handle forbidden letters
        if char not in ChileanPlateValidator.ALLOWED_LETTERS:
            forbidden_map = {
                'A': 'B', 'E': 'F', 'I': 'L', 'O': 'D', 'U': 'V',
                'M': 'W', 'N': 'W', 'Ñ': 'W', 'Q': 'G'
            }
            char = forbidden_map.get(char, 'B')  # Safe fallback
        
        return char
    
    @staticmethod
    def _correct_to_number(char: str) -> str:
        """Convert character to number"""
        if char.isdigit():
            return char
        
        letter_to_number = {
            'O': '0', 'I': '1', 'L': '1', 'S': '5', 'B': '8', 
            'G': '6', 'Z': '2', 'T': '7', 'D': '0', 'F': '7'
        }
        return letter_to_number.get(char, '0')
    
    @staticmethod
    def is_valid_format(text: str) -> str:
        """Check format and return type"""
        if not text or len(text) != 6:
            return 'invalid'
        
        if ChileanPlateValidator.MODERN_PATTERN.match(text):
            return 'modern'
        elif ChileanPlateValidator.LEGACY_PATTERN.match(text):
            return 'legacy'
        else:
            return 'invalid'

class OCREngine:
    """Simplified OCR processing"""
    
    def __init__(self, engine="easyocr"):
        self.engine = engine
        self.reader = None
        
        if engine == "easyocr" and EASYOCR_AVAILABLE:
            self.reader = easyocr.Reader(['en'], gpu=torch.cuda.is_available(), verbose=False)
        elif engine == "tesseract" and TESSERACT_AVAILABLE:
            pass  # Use pytesseract directly
        else:
            raise RuntimeError(f"OCR engine {engine} not available")
    
    def extract_text(self, image: np.ndarray, use_validation: bool = True) -> Tuple[str, str]:
        """Extract text from plate image"""
        try:
            processed = self._preprocess_image(image)
            
            # Get raw OCR text
            if self.engine == "easyocr" and self.reader:
                results = self.reader.readtext(processed, detail=0, paragraph=False)
                raw_text = ''.join(results) if results else ""
            else:
                config = '--psm 7 --oem 3 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'
                raw_text = pytesseract.image_to_string(processed, config=config).strip()
            
            # Clean raw text
            clean_raw = raw_text.upper().replace(' ', '').replace('-', '')
            
            # Apply Chilean corrections if validation enabled
            if use_validation:
                corrected_text = ChileanPlateValidator.clean_and_correct(clean_raw)
                return raw_text, corrected_text
            else:
                return raw_text, clean_raw
                
        except Exception as e:
            logger.debug(f"OCR failed: {e}")
            return "", ""
    
    def _preprocess_image(self, image: np.ndarray) -> np.ndarray:
        """Preprocess image for OCR"""
        # Convert to grayscale
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) if len(image.shape) == 3 else image.copy()
        
        # Resize if too small
        h, w = gray.shape
        if h < 80 or w < 150:
            scale = max(100/h, 200/w)
            new_h, new_w = int(h * scale), int(w * scale)
            gray = cv2.resize(gray, (new_w, new_h), interpolation=cv2.INTER_CUBIC)
        
        # Enhance image
        clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(2,2))
        gray = clahe.apply(gray)
        gray = cv2.bilateralFilter(gray, 9, 75, 75)
        gray = cv2.convertScaleAbs(gray, alpha=1.2, beta=10)
        
        return gray

class PlateCandidate:
    """Single plate candidate with confidence tracking"""
    
    def __init__(self, text: str, detection_conf: float):
        self.text = text
        self.count = 1
        self.max_detection_conf = detection_conf
        self.format_type = ChileanPlateValidator.is_valid_format(text)
    
    def update(self, detection_conf: float):
        """Update candidate with new detection"""
        self.count += 1
        self.max_detection_conf = max(self.max_detection_conf, detection_conf)
    
    def get_confidence(self, total_detections: int, min_detections: int) -> float:
        """Calculate final confidence score"""
        # Base confidence from detection rate
        detection_rate = self.count / max(total_detections, 1)
        
        # Format bonus
        format_bonus = 0.3 if self.format_type != 'invalid' else 0.0
        
        # Stability bonus (consistent detections)
        stability_bonus = 0.2 if self.count >= min_detections else 0.0
        
        # Detection quality
        detection_quality = self.max_detection_conf
        
        # Combine all factors
        confidence = (detection_rate * 0.4 + 
                     format_bonus + 
                     stability_bonus + 
                     detection_quality * 0.1)
        
        return min(1.0, confidence)

class VehicleTracker:
    """Track single vehicle and its plate candidates"""
    
    def __init__(self, track_id: int, bbox: Tuple[int, int, int, int]):
        self.track_id = track_id
        self.bbox = bbox
        self.candidates = {}  # text -> PlateCandidate
        self.total_detections = 0
        self.last_seen_frame = 0
        self.last_ocr_frame = 0
        self.best_plate = ""
        self.best_confidence = 0.0
        self.raw_text = ""
    
    def update_detection(self, bbox: Tuple[int, int, int, int], frame_count: int,
                        raw_text: str = "", plate_text: str = "", detection_conf: float = 0.0):
        """Update vehicle with new detection"""
        self.bbox = bbox
        self.last_seen_frame = frame_count
        
        if plate_text and len(plate_text) >= 4:
            self.raw_text = raw_text
            self.total_detections += 1
            
            if plate_text in self.candidates:
                self.candidates[plate_text].update(detection_conf)
            else:
                self.candidates[plate_text] = PlateCandidate(plate_text, detection_conf)
            
            self._update_best_plate()
    
    def _update_best_plate(self, min_detections: int = 2):
        """Update best plate based on confidence"""
        if not self.candidates:
            return
        
        best_candidate = None
        best_conf = 0.0
        
        for candidate in self.candidates.values():
            conf = candidate.get_confidence(self.total_detections, min_detections)
            if conf > best_conf:
                best_conf = conf
                best_candidate = candidate
        
        if best_candidate:
            self.best_plate = best_candidate.text
            self.best_confidence = best_conf
    
    def should_run_ocr(self, frame_count: int, ocr_interval: int, ocr_validation: bool) -> bool:
        """Check if should run OCR on this frame"""
        frames_since_ocr = frame_count - self.last_ocr_frame
        interval = ocr_interval if ocr_validation else ocr_interval * 2
        
        if frames_since_ocr >= interval:
            self.last_ocr_frame = frame_count
            return True
        return False
    
    def get_plate_info(self) -> Dict:
        """Get current plate information"""
        format_type = ChileanPlateValidator.is_valid_format(self.best_plate) if self.best_plate else 'invalid'
        # Get OCR confidence from best candidate
        ocr_confidence = 0.0
        if self.best_plate and self.best_plate in self.candidates:
            ocr_confidence = self.candidates[self.best_plate].max_detection_conf
        
        return {
            'plate': self.best_plate,
            'raw': self.raw_text,
            'confidence': self.best_confidence,
            'ocr_confidence': ocr_confidence,
            'format_type': format_type,
            'valid': format_type != 'invalid',
            'detections': self.total_detections
        }

class PlateTracker:
    """Manage all vehicle tracking"""
    
    def __init__(self, min_detections=2, ocr_interval=5):
        self.vehicles = {}  # track_id -> VehicleTracker
        self.frame_count = 0
        self.min_detections = min_detections
        self.ocr_interval = ocr_interval
    
    def update_frame(self):
        self.frame_count += 1
    
    def update_vehicle(self, track_id: int, bbox: Tuple[int, int, int, int],
                      raw_text: str = "", plate_text: str = "", detection_conf: float = 0.0):
        """Update vehicle tracking"""
        if track_id not in self.vehicles:
            self.vehicles[track_id] = VehicleTracker(track_id, bbox)
        
        self.vehicles[track_id].update_detection(bbox, self.frame_count, raw_text, plate_text, detection_conf)
    
    def should_run_ocr(self, track_id: int, ocr_validation: bool) -> bool:
        """Check if should run OCR for vehicle"""
        if track_id not in self.vehicles:
            return True
        return self.vehicles[track_id].should_run_ocr(self.frame_count, self.ocr_interval, ocr_validation)
    
    def get_plate_info(self, track_id: int) -> Dict:
        """Get plate info for vehicle"""
        if track_id not in self.vehicles:
            return {'plate': '', 'raw': '', 'confidence': 0.0, 'ocr_confidence': 0.0, 'format_type': 'invalid', 'valid': False, 'detections': 0}
        return self.vehicles[track_id].get_plate_info()
    
    def get_all_detections(self) -> Dict:
        """Get all vehicles with plates"""
        return {track_id: vehicle.get_plate_info() 
                for track_id, vehicle in self.vehicles.items() 
                if vehicle.best_plate}

class SimpleDetector:
    """Simplified detector base class"""
    
    def __init__(self, model_path: str, confidence: float, device: str = 'auto'):
        self.device = 'cuda' if (device == 'auto' and torch.cuda.is_available()) else device
        self.model = YOLO(model_path)
        self.confidence = confidence
        
        if self.device == 'cuda':
            self.model.to('cuda')
        
        self._warmup()
    
    def _warmup(self):
        """Warm up model"""
        if self.device == 'cuda':
            dummy = torch.randn(1, 3, 640, 640).cuda()
            with torch.no_grad():
                for _ in range(3):
                    self.model(dummy)

class VehicleDetector(SimpleDetector):
    """Vehicle detection and tracking"""
    
    def __init__(self, model_path: str, confidence: float = 0.5, device: str = 'auto'):
        super().__init__(model_path, confidence, device)
        self.vehicle_classes = [2, 3, 5, 7]  # car, motorcycle, bus, truck
    
    def detect(self, frame: np.ndarray):
        """Detect and track vehicles"""
        try:
            results = self.model.track(
                torch.from_numpy(frame).permute(2, 0, 1).unsqueeze(0),
                classes=self.vehicle_classes,
                conf=self.confidence,
                device=self.device,
                tracker='bytetrack.yaml',
                persist=True,
                verbose=False
            )
            return results[0] if results else None
        except Exception as e:
            logger.error(f"Vehicle detection failed: {e}")
            return None

class PlateDetector(SimpleDetector):
    """License plate detection"""
    
    def __init__(self, model_path: str, confidence: float = 0.25, device: str = 'auto'):
        super().__init__(model_path, confidence, device)
        self.min_size = (30, 15)  # min width, height
    
    def detect(self, vehicle_crop: np.ndarray) -> List[Tuple[np.ndarray, float]]:
        """Find plates in vehicle crop"""
        try:
            results = self.model(torch.from_numpy(vehicle_crop).permute(2, 0, 1).unsqueeze(0), 
                                 conf=self.confidence, device=self.device, verbose=False)
            plates = []
            
            if results and results[0].boxes is not None:
                for box in results[0].boxes:
                    x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
                    conf = box.conf[0].cpu().item()
                    
                    # Check minimum size
                    if (x2 - x1) >= self.min_size[0] and (y2 - y1) >= self.min_size[1]:
                        plate_crop = vehicle_crop[y1:y2, x1:x2]
                        if self._is_good_quality(plate_crop):
                            plates.append((plate_crop, conf))
            
            return sorted(plates, key=lambda x: x[1], reverse=True)
        except Exception as e:
            logger.debug(f"Plate detection failed: {e}")
            return []
    
    def _is_good_quality(self, plate_crop: np.ndarray) -> bool:
        """Check plate quality"""
        if plate_crop.size == 0:
            return False
        
        gray = cv2.cvtColor(plate_crop, cv2.COLOR_BGR2GRAY) if len(plate_crop.shape) == 3 else plate_crop
        return np.std(gray) > 15  # Basic contrast check

class DebugManager:
    """Centralized debug functionality"""
    
    def __init__(self, enabled: bool = False, output_dir: str = "debug"):
        self.enabled = enabled
        self.output_dir = output_dir
        if self.enabled:
            os.makedirs(self.output_dir, exist_ok=True)
    
    def save_plate_image(self, plate_img: np.ndarray, track_id: int, frame_count: int, 
                        raw_text: str, clean_text: str):
        """Save plate image with OCR results"""
        if not self.enabled:
            return
        
        filename = f"plate_{track_id}_frame_{frame_count}.jpg"
        filepath = os.path.join(self.output_dir, filename)
        cv2.imwrite(filepath, plate_img)
        
        # Save text info
        info_file = filepath.replace('.jpg', '_info.txt')
        with open(info_file, 'w', encoding='utf-8') as f:
            f.write(f"Track ID: {track_id}\n")
            f.write(f"Frame: {frame_count}\n")
            f.write(f"Raw OCR: {raw_text}\n")
            f.write(f"Clean Text: {clean_text}\n")
        
        logger.debug(f"Debug saved: {filename} - OCR: '{raw_text}' -> '{clean_text}'")
    
    def save_frame(self, frame: np.ndarray, frame_count: int):
        """Save current frame"""
        if not self.enabled:
            return
        
        filename = f"frame_{frame_count}.jpg"
        filepath = os.path.join(self.output_dir, filename)
        cv2.imwrite(filepath, frame)
        logger.info(f"Frame saved: {filename}")

class DisplayRenderer:
    """Handle display rendering based on mode"""
    
    def __init__(self, ocr_validation: bool = True):
        self.ocr_validation = ocr_validation
        self.class_names = {2: "Car", 3: "Motorcycle", 5: "Bus", 7: "Truck"}
        self.format_colors = {
            'modern': (60, 200, 60),    # Green
            'legacy': (200, 200, 60),   # Yellow  
            'invalid': (60, 60, 200),   # Red
        }
    
    def draw_annotations(self, frame: np.ndarray, detections: Dict, fps: float, total_plates: int) -> np.ndarray:
        """Draw all annotations on frame"""
        annotated = frame.copy()
        
        for track_id, info in detections.items():
            self._draw_vehicle_detection(annotated, track_id, info)
        
        self._draw_status_info(annotated, fps, total_plates, detections)
        return annotated
    
    def _draw_vehicle_detection(self, img: np.ndarray, track_id: int, info: Dict):
        """Draw single vehicle detection"""
        x1, y1, x2, y2 = info['bbox']
        vehicle_class = self.class_names.get(info.get('vehicle_class', 2), "Vehicle")
        
        # Get display color and confidence
        color = self._get_color(info)
        confidence = info['confidence']
        
        # Draw vehicle box
        thickness = max(1, int(confidence * 3))
        cv2.rectangle(img, (x1, y1), (x2, y2), color, thickness)
        
        # Create and draw label
        label = self._create_label(vehicle_class, track_id, info)
        self._draw_label(img, (x1, y1), label, color)
    
    def _get_color(self, info: Dict) -> Tuple[int, int, int]:
        """Get color based on detection quality"""
        if self.ocr_validation:
            if info['valid'] and info['confidence'] > 0.7:
                return self.format_colors.get(info['format_type'], (60, 200, 60))
            elif info['valid']:
                return (100, 150, 50)
            elif info['plate']:
                return (50, 140, 140)  # Yellow for detected but invalid
            else:
                return (120, 120, 255)  # Red for no detection
        else:
            # Raw mode - color by plate length
            plate_len = len(info['plate'])
            if plate_len >= 5:
                return (60, 200, 60)    # Green
            elif plate_len >= 3:
                return (50, 140, 140)   # Yellow
            else:
                return (120, 120, 255)  # Red
    
    def _create_label(self, vehicle_class: str, track_id: int, info: Dict) -> str:
        """Create display label based on mode"""
        base_label = f"{vehicle_class}:{track_id}"
        
        if not info['plate']:
            return base_label
        
        if self.ocr_validation:
            # Validation mode: show plate, format, validity, confidence
            format_type = info['format_type'].upper()[:3]
            status = "OK" if info['valid'] else "NO"
            confidence = info['confidence']
            return f"{base_label} {info['plate']} {format_type} {status} ({confidence:.2f})"
        else:
            # Raw mode: show OCR output, length, and OCR confidence
            plate = info['plate']
            length = len(plate)
            ocr_conf = info['ocr_confidence']
            return f"{base_label} {plate} L:{length} ({ocr_conf:.2f})"
    
    def _draw_label(self, img: np.ndarray, pos: Tuple[int, int], label: str, color: Tuple[int, int, int]):
        """Draw label with background"""
        font = cv2.FONT_HERSHEY_SIMPLEX
        font_scale = 0.5
        thickness = 1
        
        (text_w, text_h), _ = cv2.getTextSize(label, font, font_scale, thickness)
        x, y = pos
        
        # Background rectangle
        cv2.rectangle(img, (x, y-text_h-10), (x+text_w+6, y), color, -1)
        cv2.rectangle(img, (x, y-text_h-10), (x+text_w+6, y), (255, 255, 255), 1)
        
        # Text
        cv2.putText(img, label, (x+3, y-5), font, font_scale, (255, 255, 255), thickness)
    
    def _draw_status_info(self, img: np.ndarray, fps: float, total_plates: int, detections: Dict):
        """Draw system status information"""
        # Main status
        status = f"FPS: {fps:.1f} | Plates: {total_plates}"
        cv2.rectangle(img, (5, 5), (250, 25), (40, 40, 40), -1)
        cv2.putText(img, status, (8, 18), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)
        
        # Mode indicator
        mode = "VALIDATION" if self.ocr_validation else "RAW"
        cv2.rectangle(img, (5, 30), (120, 50), (40, 40, 40), -1)
        cv2.putText(img, f"Mode: {mode}", (8, 43), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 0), 1)
        
        # GPU usage
        if torch.cuda.is_available():
            gpu_usage = GPUManager.monitor()
            gpu_color = (0, 255, 0) if gpu_usage < 70 else (0, 255, 255) if gpu_usage < 85 else (0, 0, 255)
            cv2.rectangle(img, (5, 55), (100, 75), (40, 40, 40), -1)
            cv2.putText(img, f"GPU: {gpu_usage:.1f}%", (8, 68), cv2.FONT_HERSHEY_SIMPLEX, 0.4, gpu_color, 1)

class PlateDetectionSystem:
    """Main system orchestrator"""
    
    def __init__(self, vehicle_model: str, plate_model: str, ocr_engine: str = "easyocr", **kwargs):
        # Initialize components
        self.ocr_validation = kwargs.get('ocr_validation', True)
        self.vehicle_padding = kwargs.get('vehicle_padding', 10)
        
        # Core components
        self.vehicle_detector = VehicleDetector(vehicle_model, kwargs.get('vehicle_confidence', 0.5))
        self.plate_detector = PlateDetector(plate_model, kwargs.get('plate_confidence', 0.25))
        self.ocr = OCREngine(ocr_engine)
        self.tracker = PlateTracker(kwargs.get('min_detections', 2), kwargs.get('ocr_interval', 5))
        
        # Support components
        self.renderer = DisplayRenderer(self.ocr_validation)
        self.debug = DebugManager(kwargs.get('debug_mode', False))
        self.fps_counter = FPSCounter()
        
        logger.info(f"System initialized - Validation: {self.ocr_validation}")
    
    def process_frame(self, frame: np.ndarray) -> Dict:
        """Process single frame"""
        self.fps_counter.tick()
        self.tracker.update_frame()
        
        # Detect vehicles
        vehicle_results = self.vehicle_detector.detect(frame)
        if not vehicle_results or vehicle_results.boxes is None:
            return {}
        
        detections = {}
        
        # Process each vehicle
        for box in vehicle_results.boxes:
            if not hasattr(box, 'id') or box.id is None:
                continue
            
            track_id = int(box.id[0].cpu().item())
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
            vehicle_class = int(box.cls[0].cpu().item()) if hasattr(box, 'cls') else 2
            bbox = (x1, y1, x2, y2)
            
            # Update tracker
            self.tracker.update_vehicle(track_id, bbox)
            
            # Run OCR if needed
            if self.tracker.should_run_ocr(track_id, self.ocr_validation):
                self._process_vehicle_ocr(frame, track_id, bbox)
            
            # Get plate info for display
            plate_info = self.tracker.get_plate_info(track_id)
            detections[track_id] = {
                'bbox': bbox,
                'vehicle_class': vehicle_class,
                **plate_info
            }
        
        return detections
    
    def _process_vehicle_ocr(self, frame: np.ndarray, track_id: int, bbox: Tuple[int, int, int, int]):
        """Process OCR for single vehicle"""
        # Extract vehicle crop
        x1, y1, x2, y2 = bbox
        pad = self.vehicle_padding
        
        crop_x1 = max(0, x1 - pad)
        crop_y1 = max(0, y1 - pad)
        crop_x2 = min(frame.shape[1], x2 + pad)
        crop_y2 = min(frame.shape[0], y2 + pad)
        
        vehicle_crop = frame[crop_y1:crop_y2, crop_x1:crop_x2]
        
        # Detect plates in vehicle
        plates = self.plate_detector.detect(vehicle_crop)
        
        # Process best plate
        for plate_img, detection_conf in plates[:1]:  # Only process best plate
            raw_text, clean_text = self.ocr.extract_text(plate_img, self.ocr_validation)
            
            # Debug save
            self.debug.save_plate_image(plate_img, track_id, self.tracker.frame_count, raw_text, clean_text)
            
            # Update tracker with results
            if clean_text and len(clean_text) >= 3:
                self.tracker.update_vehicle(track_id, bbox, raw_text, clean_text, detection_conf)
    
    def draw_annotations(self, frame: np.ndarray, detections: Dict) -> np.ndarray:
        """Draw annotations on frame"""
        fps = self.fps_counter.get_fps()
        total_plates = len(self.tracker.get_all_detections())
        return self.renderer.draw_annotations(frame, detections, fps, total_plates)
    
    def save_results(self, csv_path: str):
        """Save detection results to CSV"""
        detections = self.tracker.get_all_detections()
        
        if not detections:
            logger.info("No plates detected to save")
            return
        
        results = []
        for track_id, info in detections.items():
            vehicle = self.tracker.vehicles[track_id]
            
            result = {
                'track_id': track_id,
                'plate_text': info['plate'],
                'raw_text': info['raw'],
                'confidence': info['confidence'],
                'valid_format': info['valid'],
                'format_type': info['format_type'],
                'detections': info['detections'],
                'bbox_x1': vehicle.bbox[0],
                'bbox_y1': vehicle.bbox[1],
                'bbox_x2': vehicle.bbox[2],
                'bbox_y2': vehicle.bbox[3]
            }
            results.append(result)
        
        # Sort by confidence
        results.sort(key=lambda x: x['confidence'], reverse=True)
        
        # Save to CSV
        df = pd.DataFrame(results)
        os.makedirs(os.path.dirname(csv_path), exist_ok=True)
        df.to_csv(csv_path, index=False)
        
        # Log statistics
        valid_count = sum(1 for r in results if r['valid_format'])
        logger.info(f"Saved {len(results)} detections ({valid_count} valid) to {csv_path}")

class VideoProcessor:
    """Process video files with progress monitoring"""
    
    def __init__(self, system: PlateDetectionSystem, **kwargs):
        self.system = system
        self.frame_skip = kwargs.get('frame_skip', 1)
        self.show_display = kwargs.get('show_display', True)
        self.debug = kwargs.get('debug_mode', False)
    
    def process_video(self, input_path: str, output_path: str, results_path: str):
        """Process entire video"""
        # Validate input
        if not os.path.exists(input_path):
            raise FileNotFoundError(f"Input video not found: {input_path}")
        
        # Setup video capture and writer
        cap = cv2.VideoCapture(input_path)
        if not cap.isOpened():
            raise ValueError(f"Cannot open video: {input_path}")
        
        video_info = self._get_video_info(cap)
        writer = self._setup_writer(output_path, video_info)
        
        try:
            self._process_loop(cap, writer, video_info)
        except KeyboardInterrupt:
            logger.info("Processing interrupted by user")
        finally:
            self._cleanup(cap, writer, results_path)
    
    def _get_video_info(self, cap) -> Dict:
        """Get video properties"""
        return {
            'fps': int(cap.get(cv2.CAP_PROP_FPS)),
            'width': int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),
            'height': int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)),
            'total_frames': int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        }
    
    def _setup_writer(self, output_path: str, video_info: Dict):
        """Setup video writer"""
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        return cv2.VideoWriter(output_path, fourcc, video_info['fps'], 
                             (video_info['width'], video_info['height']))
    
    def _process_loop(self, cap, writer, video_info: Dict):
        """Main processing loop"""
        frame_count = 0
        start_time = time.time()
        last_processed_frame = None
        
        logger.info(f"Processing: {video_info['width']}x{video_info['height']} @ {video_info['fps']}fps")
        logger.info(f"Total frames: {video_info['total_frames']}")
        
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            
            frame_count += 1
            
            # Process frame based on skip interval
            if frame_count % (self.frame_skip + 1) == 0:
                detections = self.system.process_frame(frame)
                processed_frame = self.system.draw_annotations(frame, detections)
                last_processed_frame = processed_frame
            elif last_processed_frame is not None:
                processed_frame = last_processed_frame
            else:
                processed_frame = frame
            
            # Write frame
            writer.write(processed_frame)
            
            # Handle display and user input
            if self.show_display:
                self._handle_display(processed_frame, frame_count)
            
            # Progress logging
            if frame_count % 150 == 0:
                self._log_progress(frame_count, video_info['total_frames'], start_time)
    
    def _handle_display(self, frame: np.ndarray, frame_count: int):
        """Handle display window and keyboard input"""
        cv2.imshow('Chilean License Plate Detection', frame)
        key = cv2.waitKey(1) & 0xFF
        
        if key == ord('q'):
            raise KeyboardInterrupt
        elif key == ord('s'):
            self.system.debug.save_frame(frame, frame_count)
        elif key == ord(' '):  # Pause
            logger.info("Paused - press any key to continue")
            cv2.waitKey(0)
    
    def _log_progress(self, frame_count: int, total_frames: int, start_time: float):
        """Log processing progress"""
        elapsed = time.time() - start_time
        fps = frame_count / elapsed if elapsed > 0 else 0
        plates = len(self.system.tracker.get_all_detections())
        progress = (frame_count / total_frames) * 100
        
        # ETA calculation
        eta_seconds = (total_frames - frame_count) / fps if fps > 0 else 0
        eta_min, eta_sec = divmod(int(eta_seconds), 60)
        
        logger.info(f"Progress: {frame_count}/{total_frames} ({progress:.1f}%) | "
                   f"FPS: {fps:.1f} | Plates: {plates} | ETA: {eta_min}m{eta_sec:02d}s")
        
        # GPU monitoring
        if torch.cuda.is_available():
            gpu_usage = GPUManager.monitor()
            if gpu_usage > 80:
                logger.warning(f"High GPU usage: {gpu_usage:.1f}%")
    
    def _cleanup(self, cap, writer, results_path: str):
        """Cleanup resources and save results"""
        cap.release()
        writer.release()
        cv2.destroyAllWindows()
        
        # Save results
        self.system.save_results(results_path)
        
        # Final statistics
        total_vehicles = len(self.system.tracker.vehicles)
        total_plates = len(self.system.tracker.get_all_detections())
        valid_plates = sum(1 for info in self.system.tracker.get_all_detections().values() 
                          if info['valid'])
        
        logger.info("=" * 50)
        logger.info("PROCESSING COMPLETED")
        logger.info(f"Vehicles tracked: {total_vehicles}")
        logger.info(f"Plates detected: {total_plates}")
        logger.info(f"Valid plates: {valid_plates}")
        logger.info(f"Results saved: {results_path}")
        logger.info("=" * 50)

def process_video(vehicle_model: str, plate_model: str, input_video: str,
                 output_video: str, results_csv: str, **kwargs):
    """Main video processing function"""
    
    # Validate files exist
    for path in [vehicle_model, plate_model, input_video]:
        if not os.path.exists(path):
            raise FileNotFoundError(f"File not found: {path}")
    
    # Initialize system
    system = PlateDetectionSystem(vehicle_model, plate_model, **kwargs)
    processor = VideoProcessor(system, **kwargs)
    
    # Process video
    processor.process_video(input_video, output_video, results_csv)

def main():
    """Main function with optimized configuration"""
    
    # Initialize GPU
    cuda_available = GPUManager.setup()
    
    # Configuration
    config = {
        # Model paths
        'vehicle_model': "../checkpoints/model_weights/yolov8s.pt",
        'plate_model': "../checkpoints/model_weights/license_plate_detector.pt", 
        
        # Input/Output
        'input_video': "../data/input/Video4.mp4",
        'output_video': "../data/output/tracked_plates.mp4",
        'results_csv': "../data/output/plate_results.csv",
        
        # Processing settings
        'frame_skip': 2,
        'ocr_engine': "easyocr",
        'ocr_validation': False,  # Set to False for raw mode
        'show_display': True,
        'debug_mode': False,
        
        # Detection thresholds
        'vehicle_confidence': 0.5,
        'plate_confidence': 0.1,
        
        # Tracking settings
        'min_detections': 2,
        'ocr_interval': 3,
        'vehicle_padding': 10,
        
        # Device
        'device': 'auto'
    }
    
    print("=" * 70)
    print("CHILEAN LICENSE PLATE DETECTION SYSTEM - SIMPLIFIED")
    print("=" * 70)
    print("Improvements:")
    print("• Fixed confidence calculation (proper tracking-based confidence)")
    print("• Simplified raw mode display (OCR output only)")
    print("• Centralized debug system with image + text info")
    print("• Single responsibility classes")
    print("• Reduced code complexity")
    print("• Maintained all original capabilities")
    print("-" * 70)
    
    mode = "VALIDATION MODE" if config['ocr_validation'] else "RAW MODE"
    print(f"Current Mode: {mode}")
    
    if config['ocr_validation']:
        print("• Validates Chilean format (modern LLLLNN, legacy LLNNNN)")
        print("• Applies V/W character corrections")
        print("• Shows format type and validity")
    else:
        print("• Shows raw OCR output only")
        print("• No format validation")
        print("• Faster processing")
    
    print(f"GPU Available: {cuda_available}")
    print(f"Debug Mode: {config['debug_mode']}")
    print("-" * 70)
    
    try:
        process_video(
            config['vehicle_model'],
            config['plate_model'], 
            config['input_video'],
            config['output_video'],
            config['results_csv'],
            **{k: v for k, v in config.items() if k not in 
               ['vehicle_model', 'plate_model', 'input_video', 'output_video', 'results_csv']}
        )
        print("\nProcessing completed successfully!")
        
    except Exception as e:
        print(f"\nError: {e}")
        logger.error(f"Processing failed: {e}")

if __name__ == "__main__":
    main()
# Out:
# 2025-08-30 17:32:22,169 - GPU optimized
# ======================================================================
# CHILEAN LICENSE PLATE DETECTION SYSTEM - SIMPLIFIED
# ======================================================================
# Improvements:
# • Fixed confidence calculation (proper tracking-based confidence)
# • Simplified raw mode display (OCR output only)
# • Centralized debug system with image + text info
# • Single responsibility classes
# • Reduced code complexity
# • Maintained all original capabilities
# ----------------------------------------------------------------------
# Current Mode: RAW MODE
# • Shows raw OCR output only
# • No format validation
# • Faster processing
# GPU Available: True
# Debug Mode: False
# ----------------------------------------------------------------------
#
# WARNING ⚠️ torch.Tensor inputs should be normalized 0.0-1.0 but max value is 5.392364501953125. Dividing input by 255.
# 0: 640x640 (no detections), 56.0ms
# Speed: 2.3ms preprocess, 56.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING ⚠️ torch.Tensor inputs should be normalized 0.0-1.0 but max value is 5.392364501953125. Dividing input by 255.
# 0: 640x640 (no detections), 53.2ms
# Speed: 0.0ms preprocess, 53.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING ⚠️ torch.Tensor inputs should be normalized 0.0-1.0 but max value is 5.392364501953125. Dividing input by 255.
# 0: 640x640 (no detections), 52.4ms
# Speed: 0.0ms preprocess, 52.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING ⚠️ torch.Tensor inputs should be normalized 0.0-1.0 but max value is 5.28354549407959. Dividing input by 255.
# 0: 640x640 (no detections), 21.7ms
# Speed: 0.0ms preprocess, 21.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING ⚠️ torch.Tensor inputs should be normalized 0.0-1.0 but max value is 5.28354549407959. Dividing input by 255.
# 0: 640x640 (no detections), 21.8ms
# Speed: 0.0ms preprocess, 21.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING ⚠️ torch.Tensor inputs should be normalized 0.0-1.0 but max value is 5.28354549407959. Dividing input by 255.
# 0: 640x640 (no detections), 22.1ms
# Speed: 0.0ms preprocess, 22.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# 2025-08-30 17:32:26,083 - System initialized - Validation: False
# 2025-08-30 17:32:26,098 - Processing: 854x480 @ 29fps
# 2025-08-30 17:32:26,099 - Total frames: 9646
# 2025-08-30 17:32:26,147 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,176 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,205 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,233 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,260 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,289 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,316 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,345 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,375 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,403 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,430 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,462 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,492 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,523 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,553 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,583 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,612 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,639 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,668 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,697 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,724 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,752 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,782 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,813 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,842 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,869 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,897 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,924 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,953 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:26,980 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,005 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,031 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,059 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,085 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,113 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,141 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,174 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,199 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,228 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,257 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,287 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,313 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,342 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,370 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,399 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,429 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,459 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,486 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,515 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,545 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,555 - Progress: 150/9646 (1.6%) | FPS: 103.0 | Plates: 0 | ETA: 1m32s
# 2025-08-30 17:32:27,572 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,601 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,632 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,658 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,686 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,712 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,742 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,770 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,796 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,824 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,854 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,878 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,909 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,937 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,965 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:27,992 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,021 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,048 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,075 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,104 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,130 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,160 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,191 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,220 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,244 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,272 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,299 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,325 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,353 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,379 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,408 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,433 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,459 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,486 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,514 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,542 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,570 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,596 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,625 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,658 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,686 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,713 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,742 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,770 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,795 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,824 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,854 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,876 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,906 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,942 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:28,959 - Progress: 300/9646 (3.1%) | FPS: 104.9 | Plates: 0 | ETA: 1m29s
# 2025-08-30 17:32:28,985 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,011 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,040 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,071 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,100 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,128 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,155 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,184 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,214 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,244 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,272 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,304 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,334 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,363 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,391 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,419 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,450 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,480 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,507 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,537 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,565 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,593 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,621 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,645 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,673 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,699 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,726 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,754 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,781 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,809 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,838 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:29,986 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,012 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,038 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,066 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,091 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,121 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,147 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,175 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,203 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,230 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,257 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,287 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,315 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,342 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,369 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,394 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,421 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,451 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,475 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,487 - Progress: 450/9646 (4.7%) | FPS: 102.5 | Plates: 0 | ETA: 1m29s
# 2025-08-30 17:32:30,509 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,539 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,568 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,597 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,624 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,653 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,683 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,710 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,736 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,765 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,793 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,818 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,846 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,873 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,900 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,928 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,958 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:30,984 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,014 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,040 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,068 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,097 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,125 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,151 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,180 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,210 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,240 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,267 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,297 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,326 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,356 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,384 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,413 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,437 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,465 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,494 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,520 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,547 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,574 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,599 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,625 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,650 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,680 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,708 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,734 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,760 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,785 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,813 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,837 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,865 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,875 - Progress: 600/9646 (6.2%) | FPS: 103.9 | Plates: 0 | ETA: 1m27s
# 2025-08-30 17:32:31,895 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,919 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,947 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:31,984 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,024 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,049 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,077 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,103 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,136 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,164 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,192 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,219 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,249 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,277 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,307 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,333 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,363 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,392 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,418 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,446 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,474 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,500 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,529 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,553 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,582 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,609 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,639 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,665 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,694 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,718 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,746 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,771 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,800 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,829 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,857 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,884 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,913 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,941 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,967 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:32,995 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:33,021 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:33,048 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:33,075 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:33,101 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:33,132 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:33,158 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# ...
# 2025-08-30 17:32:53,712 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:53,741 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:53,768 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:53,796 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:53,824 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:53,853 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:53,878 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:53,911 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:53,937 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:53,967 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:53,996 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,052 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,088 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,116 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,142 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,170 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,199 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,228 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,258 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,286 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,320 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,345 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,373 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,404 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,438 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,466 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,492 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,521 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,550 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,584 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,617 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,651 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,685 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,719 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,754 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,779 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,806 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,837 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,868 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,895 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,906 - Progress: 3000/9646 (31.1%) | FPS: 104.1 | Plates: 0 | ETA: 1m03s
# 2025-08-30 17:32:54,926 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,956 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:54,986 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,019 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,046 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,076 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,109 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,146 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,184 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,213 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,242 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,273 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,300 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,330 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,365 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,393 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,424 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,452 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,481 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,511 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,541 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,569 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,597 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,628 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,660 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,686 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,716 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,746 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,774 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,802 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,829 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,857 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,890 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,920 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,948 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:55,976 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:56,008 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:56,037 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:56,068 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:56,097 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:56,125 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:56,157 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:56,187 - Vehicle detection failed: torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(1, 3, 480, 854) is incompatible.
# 2025-08-30 17:32:56,218 - Processing interrupted by user
# 2025-08-30 17:32:56,338 - No plates detected to save
# 2025-08-30 17:32:56,339 - ==================================================
# 2025-08-30 17:32:56,340 - PROCESSING COMPLETED
# 2025-08-30 17:32:56,342 - Vehicles tracked: 0
# 2025-08-30 17:32:56,345 - Plates detected: 0
# 2025-08-30 17:32:56,346 - Valid plates: 0
# 2025-08-30 17:32:56,347 - Results saved: ../data/output/plate_results.csv
# 2025-08-30 17:32:56,348 - ==================================================
# Processing completed successfully!
